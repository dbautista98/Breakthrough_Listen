# %%
import numpy as np
import pandas as pd
import glob
import os
from astropy.time import Time

# %%
dat_files = glob.glob("gbt_dats/traas_dats/full_lband/*dat")
dat_files[0]
# Out:
# 'gbt_dats/traas_dats/full_lband/spliced_blc4041424344454647_guppi_58844_09167_HIP95194_0023.gpuspec.0000.dat'

# %%
def format_directory(dir_path, band):
    dat_files = glob.glob(dir_path)
    file_names = np.empty_like(dat_files)
    julian_day = np.empty_like(dat_files)
    julian_second = np.empty_like(dat_files)
    band_name = []
    for i in range(len(dat_files)):
        file_names[i] = os.path.basename(dat_files[i])
        julian_day[i] = file_names[i].split("_")[3]
        julian_second[i] = file_names[i].split("_")[4]
        band_name.append(band)
    data_dict = {"filename":file_names, "band":band_name, "julian day":julian_day, "julian second":julian_second}
    df = pd.DataFrame(data_dict)
    return df

# %%
l_band = format_directory("gbt_dats/traas_dats/full_lband/*dat", "L")
s_band = format_directory("gbt_dats/traas_dats/full_sband/*dat", "S")
c_band = format_directory("gbt_dats/traas_dats/full_cband/*dat", "C")
x_band = format_directory("gbt_dats/traas_dats/full_xband/*dat", "X")

# %%
all_files = pd.concat([l_band, s_band, c_band, x_band], axis=0, ignore_index=True)
all_files
# Out:
#                                               filename band julian day  \
# 0    spliced_blc4041424344454647_guppi_58844_09167_...    L      58844
# 1    spliced_blc4041424344454647_guppi_58885_62397_...    L      58885
# 2    spliced_blc4041424344454647_guppi_58885_59164_...    L      58885
# 3    spliced_blc5051525354555657_guppi_58892_34784_...    L      58892
# 4    spliced_blc4041424344454647_guppi_58844_06267_...    L      58844
# ..                                                 ...  ...        ...
# 646  spliced_blc00010203040506o7o0111213141516o0212...    X      58806
# 647  spliced_blc00010203040506o7o0111213141516o7o02...    X      58810
# 648  spliced_blc10111213141516o7o0212223242526o7o03...    X      58868
# 649  spliced_blc00010203040506o7o0111213141516o7o02...    X      58810
# 650  spliced_blc00010203040506o7o0111213141516o7o02...    X      58808
#
#     julian second
# 0           09167
# 1           62397
# 2           59164
# 3           34784
# 4           06267
# ..            ...
# 646         42870
# 647         10766
# 648         40636
# 649         17084
# 650         60850
#
# [651 rows x 4 columns]

# %%
def julian_to_yyyymmdd(julian_day, julian_second):
    total_date = np.empty_like(julian_day)
    for i in range(len(julian_day)):
        total_date[i] = julian_day[i] + "." + julian_second[i]
    times = list(total_date)
    t = Time(times, format="mjd")
    return t.isot

# %%
times = julian_to_yyyymmdd(all_files["julian day"].values, all_files["julian second"])
all_files["yyyymmdd"] = times

# %%
all_files.sort_values("yyyymmdd")
# Out:
#                                               filename band julian day  \
# 477  spliced_blc40414243444546o7o0515253545556o7o06...    C      58744
# 474  spliced_blc40414243444546o7o0515253545556o7o06...    C      58744
# 478  spliced_blc40414243444546o7o0515253545556o7o06...    C      58744
# 399  spliced_blc40414243444546o7o0515253545556o7o06...    C      58744
# 432  spliced_blc40414243444546o7o0515253545556o7o06...    C      58744
# ..                                                 ...  ...        ...
# 118  spliced_blc0001020304050607_guppi_58965_60374_...    L      58965
# 61   spliced_blc0001020304050607_guppi_58965_60691_...    L      58965
# 48   spliced_blc0001020304050607_guppi_58965_61011_...    L      58965
# 124  spliced_blc0001020304050607_guppi_58965_61330_...    L      58965
# 35   spliced_blc0001020304050607_guppi_58965_61650_...    L      58965
#
#     julian second                 yyyymmdd
# 477         13593  2019-09-18T03:15:44.352
# 474         13914  2019-09-18T03:20:21.696
# 478         14235  2019-09-18T03:24:59.040
# 399         14558  2019-09-18T03:29:38.112
# 432         14881  2019-09-18T03:34:17.184
# ..            ...                      ...
# 118         60374  2020-04-26T14:29:23.136
# 61          60691  2020-04-26T14:33:57.024
# 48          61011  2020-04-26T14:38:33.504
# 124         61330  2020-04-26T14:43:09.120
# 35          61650  2020-04-26T14:47:45.600
#
# [651 rows x 5 columns]

# %% [markdown]
# ## Save DataFrame to csv

# %%
all_files.to_csv("file_dates.csv")

# %% [markdown]
# ## Here are the earliest and most recently observed files from the bl_tess dataset

# %%
all_files.sort_values("yyyymmdd")["yyyymmdd"].iloc[0], all_files.sort_values("yyyymmdd")["yyyymmdd"].iloc[-1]
# Out:
# ('2019-09-18T03:15:44.352', '2020-04-26T14:47:45.600')
